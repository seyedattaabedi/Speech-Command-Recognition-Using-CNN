# %%
import os
import pathlib

import numpy as np
import seaborn as sns
import tensorflow as tf

from keras.layers import Conv2D,Flatten,Dense,MaxPooling2D,Dropout,Resizing,Input,Normalization
from keras import models
from keras.models import Sequential
import matplotlib.pyplot as plt
# %matplotlib widget

from IPython import display

# %%
DATASET_PATH = 'data/'

data_dir = pathlib.Path(DATASET_PATH)


tf.keras.utils.get_file(
    'voicedataset.zip',
    #origin="",
    extract=True,
    cache_dir='.', cache_subdir='data')

print("DONE!")
# Out:
# Downloading data from http://aiolearn.com/dl/datasets/voicedata.zip
# 178676098/178676098 [==============================] - 24s 0us/step
# DONE!

# %%
tf.io.gfile.listdir(str(data_dir))
# Out:
# ['down',
#  'go',
#  'left',
#  'no',
#  'README.md',
#  'right',
#  'stop',
#  'up',
#  'voicedataset.zip',
#  'yes']

# %%
commands = np.array(tf.io.gfile.listdir(str(data_dir)))
commands = commands[(commands != 'README.md') & (commands != '.DS_Store') & (commands != 'voicedataset.zip')]
print('Commands Available:', commands)
# Out:
# Commands Available: ['down' 'go' 'left' 'no' 'right' 'stop' 'up' 'yes']

# %%
X_train, X_test = tf.keras.utils.audio_dataset_from_directory(
    directory=data_dir,
    batch_size=64,
    validation_split=0.2,
    seed=0,
    output_sequence_length=16000,
    subset='both')

label_names = np.array(X_train.class_names)
print()
print("label :", label_names)
# Out:
# Found 8000 files belonging to 8 classes.
# Using 6400 files for training.
# Using 1600 files for validation.
#
# label : ['down' 'go' 'left' 'no' 'right' 'stop' 'up' 'yes']

# %%
def squeeze(audio, labels):
  audio = tf.squeeze(audio, axis=-1)
  return audio, labels

X_train = X_train.map(squeeze, tf.data.AUTOTUNE)
X_test= X_test.map(squeeze, tf.data.AUTOTUNE)

# %%
X_train.element_spec
# Out:
# (TensorSpec(shape=(None, 16000), dtype=tf.float32, name=None),
#  TensorSpec(shape=(None,), dtype=tf.int32, name=None))

# %%
val=X_test
X_test = X_test.shard(num_shards=2, index=0)
val = X_test.shard(num_shards=2, index=1)

# %%
for x, y in X_train.take(1):  
  print(x)
  print(label_names[y])
# Out:
# tf.Tensor(
# [[ 2.3498535e-03  2.9296875e-03  3.4179688e-03 ...  0.0000000e+00
#    0.0000000e+00  0.0000000e+00]
#  [-1.4038086e-03 -1.8920898e-03 -1.8005371e-03 ...  0.0000000e+00
#    0.0000000e+00  0.0000000e+00]
#  [ 0.0000000e+00 -3.0517578e-05 -3.0517578e-05 ... -5.4931641e-04
#   -3.6621094e-04 -5.4931641e-04]
#  ...
#  [-1.5258789e-04 -1.8310547e-04 -1.2207031e-04 ...  1.8310547e-04
#    2.1362305e-04  2.7465820e-04]
#  [-1.8310547e-04 -2.4414062e-04 -3.3569336e-04 ... -2.4414062e-04
#   -2.1362305e-04 -2.4414062e-04]
#  [-4.6691895e-03 -1.5502930e-02 -1.5594482e-02 ... -2.5573730e-02
#   -1.7059326e-02 -1.2817383e-02]], shape=(64, 16000), dtype=float32)
# ['right' 'down' 'down' 'right' 'up' 'yes' 'left' 'go' 'stop' 'stop' 'down'
#  'left' 'left' 'up' 'yes' 'go' 'up' 'stop' 'yes' 'yes' 'yes' 'right' 'up'
#  'right' 'stop' 'up' 'up' 'yes' 'yes' 'no' 'up' 'stop' 'no' 'up' 'right'
#  'left' 'go' 'up' 'yes' 'stop' 'stop' 'up' 'down' 'no' 'left' 'left' 'no'
#  'right' 'left' 'yes' 'go' 'right' 'right' 'up' 'up' 'go' 'stop' 'yes'
#  'go' 'go' 'right' 'yes' 'down' 'up']

# %%
for example_audio, example_labels in X_train.take(1):  
  print(example_audio.shape)
  print(example_labels.shape)
# Out:
# (64, 16000)
# (64,)

# %%
label_names[[0,1,2]]
# Out:
# array(['down', 'go', 'left'], dtype='<U5')

# %%
example_audio[0][5100]
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=-0.45635986>

# %%
plt.figure(figsize=(10, 10))
rows = 3
cols = 3
n = rows * cols
for i in range(n):
  plt.subplot(rows, cols, i+1)
  audio_signal = example_audio[i]
  plt.plot(audio_signal)
  plt.title(label_names[example_labels[i]])
  plt.yticks(np.arange(-1.2, 1.2, 0.2))
  plt.ylim([-1.1, 1.1])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def get_spectrogram(waveform):
  # Convert the waveform to a spectrogram via a STFT.
  spectrogram = tf.signal.stft(
      waveform, frame_length=255, frame_step=128)
  # Obtain the magnitude of the STFT.
  spectrogram = tf.abs(spectrogram)
  # Add a `channels` dimension, so that the spectrogram can be used
  # as image-like input data with convolution layers (which expect
  # shape (`batch_size`, `height`, `width`, `channels`).
  spectrogram = spectrogram[..., tf.newaxis]
  return spectrogram

# %%
for i in range(3):
  label = label_names[example_labels[i]]
  waveform = example_audio[i]
  spectrogram = get_spectrogram(waveform)

  print('Label:', label)
  print('Waveform shape:', waveform.shape)
  print('Spectrogram shape:', spectrogram.shape)
  print('Audio playback')
  display.display(display.Audio(waveform, rate=16000))
# Out:
# Label: down
# Waveform shape: (16000,)
# Spectrogram shape: (124, 129, 1)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Label: left
# Waveform shape: (16000,)
# Spectrogram shape: (124, 129, 1)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Label: up
# Waveform shape: (16000,)
# Spectrogram shape: (124, 129, 1)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def plot_spectrogram(spectrogram, ax):
  if len(spectrogram.shape) > 2:
    assert len(spectrogram.shape) == 3
    spectrogram = np.squeeze(spectrogram, axis=-1) 
  log_spec = np.log(spectrogram.T + np.finfo(float).eps)
  height = log_spec.shape[0]
  width = log_spec.shape[1]
  X = np.linspace(0, np.size(spectrogram), num=width, dtype=int)
  Y = range(height)
  ax.pcolormesh(X, Y, log_spec)

# %%
plt.close()
fig, axes = plt.subplots(2, figsize=(10, 8))
timescale = np.arange(waveform.shape[0])
axes[0].plot(timescale, waveform.numpy())
axes[0].set_title('Waveform')
axes[0].set_xlim([0, 16000])

plot_spectrogram(spectrogram.numpy(), axes[1])
axes[1].set_title('Spectrogram')

plt.suptitle(label.title())
plt.show()

display.display(display.Audio(waveform, rate=16000))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def make_spec_ds(ds):
  return ds.map(
      map_func=lambda audio,label: (get_spectrogram(audio), label),
      num_parallel_calls=tf.data.AUTOTUNE)

# %%
train_spectrogram_ds = make_spec_ds(X_train)
val_spectrogram_ds = make_spec_ds(val)
test_spectrogram_ds = make_spec_ds(X_test)

# %%
for example_spectrograms, example_spect_labels in train_spectrogram_ds.take(1):
  break

# %%
rows = 3
cols = 3
n = rows*cols
fig, axes = plt.subplots(rows, cols, figsize=(10, 9))

for i in range(n):
    r = i // cols
    c = i % cols
    ax = axes[r][c]
    plot_spectrogram(example_spectrograms[i].numpy(), ax)
    ax.set_title(label_names[example_spect_labels[i].numpy()])

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
train_spectrogram_ds = train_spectrogram_ds.cache().shuffle(10000).prefetch(tf.data.AUTOTUNE)
val_spectrogram_ds = val_spectrogram_ds.cache().prefetch(tf.data.AUTOTUNE)
test_spectrogram_ds = test_spectrogram_ds.cache().prefetch(tf.data.AUTOTUNE)

# %%
example_spectrograms.shape[1:]
# Out:
# TensorShape([124, 129, 1])

# %%
input_shape = example_spectrograms.shape[1:]
print('Input shape:', input_shape)
num_labels = len(label_names)
 
norm_layer = Normalization() 
norm_layer.adapt(data=train_spectrogram_ds.map(map_func=lambda spec, label: spec))

model = models.Sequential([
    Input(shape=input_shape),
    # Downsample the input.
    Resizing(32, 32),
    # Normalize.
    norm_layer,
    Conv2D(32, 3, activation='relu'),
    Conv2D(64, 3, activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(8),
])

model.summary()
# Out:
# Input shape: (124, 129, 1)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resizing (Resizing)         (None, 32, 32, 1)         0
#
#  normalization (Normalizatio  (None, 32, 32, 1)        3
#  n)
#
#  conv2d (Conv2D)             (None, 30, 30, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 64)        18496
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 64)       0
#  )
#
#  dropout (Dropout)           (None, 14, 14, 64)        0
#
#  flatten (Flatten)           (None, 12544)             0
#
#  dense (Dense)               (None, 128)               1605760
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 8)                 1032
#
# =================================================================
# Total params: 1,625,611
# Trainable params: 1,625,608
# Non-trainable params: 3
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'],
)

# %%
history = model.fit(
    train_spectrogram_ds,
    validation_data=val_spectrogram_ds,
    epochs=10,
    callbacks=tf.keras.callbacks.EarlyStopping(verbose=1, patience=2),
)
# Out:
# Epoch 1/10
# 100/100 [==============================] - 10s 89ms/step - loss: 1.7510 - accuracy: 0.3691 - val_loss: 1.4217 - val_accuracy: 0.5339
# Epoch 2/10
# 100/100 [==============================] - 7s 74ms/step - loss: 1.2262 - accuracy: 0.5688 - val_loss: 0.9809 - val_accuracy: 0.6823
# Epoch 3/10
# 100/100 [==============================] - 8s 77ms/step - loss: 0.9442 - accuracy: 0.6689 - val_loss: 0.8206 - val_accuracy: 0.7109
# Epoch 4/10
# 100/100 [==============================] - 9s 88ms/step - loss: 0.7881 - accuracy: 0.7225 - val_loss: 0.7036 - val_accuracy: 0.7656
# Epoch 5/10
# 100/100 [==============================] - 8s 77ms/step - loss: 0.6662 - accuracy: 0.7648 - val_loss: 0.6337 - val_accuracy: 0.7839
# Epoch 6/10
# 100/100 [==============================] - 8s 75ms/step - loss: 0.5807 - accuracy: 0.7919 - val_loss: 0.6237 - val_accuracy: 0.7943
# Epoch 7/10
# 100/100 [==============================] - 7s 72ms/step - loss: 0.5234 - accuracy: 0.8156 - val_loss: 0.5347 - val_accuracy: 0.8047
# Epoch 8/10
# 100/100 [==============================] - 7s 74ms/step - loss: 0.4667 - accuracy: 0.8342 - val_loss: 0.5290 - val_accuracy: 0.8255
# Epoch 9/10
# 100/100 [==============================] - 7s 74ms/step - loss: 0.4171 - accuracy: 0.8494 - val_loss: 0.5329 - val_accuracy: 0.8125
# Epoch 10/10
# 100/100 [==============================] - 7s 72ms/step - loss: 0.3822 - accuracy: 0.8656 - val_loss: 0.4666 - val_accuracy: 0.8333

# %%
metrics = history.history
plt.close()
plt.figure(figsize=(10,6))
plt.subplot(1,2,1)
plt.plot(history.epoch, metrics['loss'], metrics['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.ylim([0, max(plt.ylim())])
plt.xlabel('Epoch')
plt.ylabel('Loss [CrossEntropy]')

plt.subplot(1,2,2)
plt.plot(history.epoch, 100*np.array(metrics['accuracy']), 100*np.array(metrics['val_accuracy']))
plt.legend(['accuracy', 'val_accuracy'])
plt.ylim([0, 100])
plt.xlabel('Epoch')
plt.ylabel('Accuracy [%]')
# Out:
# Text(0, 0.5, 'Accuracy [%]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
model.evaluate(test_spectrogram_ds, return_dict=True)
# Out:
# 13/13 [==============================] - 0s 17ms/step - loss: 0.4585 - accuracy: 0.8329
# {'loss': 0.4585418403148651, 'accuracy': 0.832932710647583}

# %%
y_pred = model.predict(test_spectrogram_ds)
# Out:
# 13/13 [==============================] - 0s 16ms/step

# %%
y_pred = tf.argmax(y_pred, axis=1)

# %%
y_true = tf.concat(list(test_spectrogram_ds.map(lambda s,lab: lab)), axis=0)

# %%
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(confusion_mtx,
            xticklabels=label_names,
            yticklabels=label_names,
            annot=True, fmt='g')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import IPython.display
 
x = data_dir/'stop/1c45ceb2_nohash_1.wav'
x = tf.io.read_file(str(x))


plt.close()

x, sample_rate = tf.audio.decode_wav(x, desired_channels=1, desired_samples=16000,)
x = tf.squeeze(x, axis=-1)
waveform = x
x = get_spectrogram(x)
x = x[tf.newaxis,...]

prediction = model(x)
x_labels = label_names
plt.close()
plt.bar(x_labels, tf.nn.softmax(prediction[0]))
plt.title('No')
plt.show()

display.display(display.Audio(waveform, rate=16000,autoplay=True))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import IPython.display
 
x = 'data/stop/8a28231e_nohash_0.wav'
x = tf.io.read_file(str(x))
x, sample_rate = tf.audio.decode_wav(x, desired_channels=1, desired_samples=16000,)
x = tf.squeeze(x, axis=-1)
waveform = x
display.display(display.Audio(waveform, rate=16000,autoplay=True))
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
IPython.__version__
# Out:
# '8.10.0'

# %%
import pyaudio
p = pyaudio.PyAudio()
sabad=16000
stream = p.open(format=pyaudio.paInt16, channels=1, rate=16000,input=True,frames_per_buffer=sabad )
a=stream.read(sabad)

import wave
wf = wave.open("majid.wav", 'wb')
wf.setnchannels(1)
wf.setsampwidth(p.get_sample_size(pyaudio.paInt16))
wf.setframerate(16000 )
wf.writeframes(b''.join([a]))
wf.close()

x = 'majid.wav'
x = tf.io.read_file(str(x))
 

x, sample_rate = tf.audio.decode_wav(x, desired_channels=1, desired_samples=16000,)
x = tf.squeeze(x, axis=-1)
waveform = x
x = get_spectrogram(x)
x = x[tf.newaxis,...]

prediction = model(x)
x_labels = label_names
plt.close()
plt.bar(x_labels, tf.nn.softmax(prediction[0]))
plt.title('Out')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
model.save_weights('model.h5')
